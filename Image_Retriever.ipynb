# %% [markdown]
# ## This workbook pulls photos of the input buildings from Google Streetview API
#
# Built off of docs at: https://pypi.org/project/google-streetview/
# and guide at https://andrewpwheeler.wordpress.com/2015/12/28/using-python-to-grab-google-street-view-imagery/

# %%
import numpy as np
import scipy as sp
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import math
import itertools
from scipy.spatial.distance import cdist
import os
import urllib
import xlrd

# %%
# this implementation uses url modification directly, may not be the fastest
# works once I got my API key paid for! 
#import urllib, os, urllib.parse, urllib.request

#base code from: https://andrewpwheeler.wordpress.com/2015/12/28/using-python-to-grab-google-street-view-imagery/

myloc = r"C:\Users\pseufert\Documents\MIE1516\Project" #replace with own folder for use
key = "&key=" + "AIzaSyBDvwuu00ZJHqepBLcRqjxryDW1s3k0kFo" #add key to make this work
signature = "&signature=" + "O486henUwvfFrb8xT2WzWQW5Urc="
    #Key 1: AIzaSyCFNUxS3m1uPTw_Rm0xYpMEvMK-RJVCUa0
    #key 2: AIzaSyA2o8XSFKdtZx_LTFdhoxXPKqQdXAXP0vo
    #key 3: AIzaSyBDvwuu00ZJHqepBLcRqjxryDW1s3k0kFo
    #key 4: AIzaSyC-9Br_GU0b660u_5dnAhkIAKu98iKd1zA

def GetStreet(Add,SaveLoc):
    base = "https://maps.googleapis.com/maps/api/streetview?size=600x400&location="
    #for python 3: urllib.parse.quote_plus
    MyUrl = base + urllib.quote_plus(Add) + key #+ signature #added url encoding
    fi = Add + ".jpg"
    #for python 3: urllib.request.urlretrieve
    urllib.urlretrieve(MyUrl, os.path.join(SaveLoc,fi))

# %%
#takes 2ish seconds
labeledDF = pd.read_excel('Classifier_Building_Data.xlsx', sheet_name='Sheet2')

# %%
retrieveList = labeledDF['Address'].tolist()

# %%
len(retrieveList)
# Out:
# 10137

# %%
for i in range(0, labeledDF.shape[0]):
    retrieveList[i] = str(retrieveList[i]) + ", Toronto, Ontario"

# %%
#loop over all elements in the retriveList, saving them to folders (different folder for every 500 for easy testing)
counter = 0
loopCounter = 20
subPath = myloc + "/"+str(loopCounter)
os.mkdir(subPath)

for i in range(9701, 10137):
    counter += 1
    if(counter == 501):
        #all my file heirarchy logic
        counter = 1
        loopCounter += 1
        subPath = myloc + "/"+str(loopCounter)
        os.mkdir(subPath)
        print i
    GetStreet(Add=retrieveList[i],SaveLoc=subPath)

# %%
subPath = myloc + "/test"

# %%
os.mkdir(subPath)

# %%
labeledDF
# Out:
#                   Address      New Typology
# 0       548 BROOKDALE AVE    Detached House
# 1         361 JOICEY BLVD    Detached House
# 2       23 TARRAGONA BLVD    Attached House
# 3            56 VIELLA ST    Attached House
# 4            58 VIELLA ST    Attached House
# 5       33 TARRAGONA BLVD    Attached House
# 6            63 VIELLA ST    Attached House
# 7       17 TARRAGONA BLVD    Attached House
# 8       21 TARRAGONA BLVD    Attached House
# 9       31 TARRAGONA BLVD    Attached House
# 10      29 TARRAGONA BLVD    Attached House
# 11      19 TARRAGONA BLVD    Attached House
# 12      34 TARRAGONA BLVD    Attached House
# 13      27 TARRAGONA BLVD    Attached House
# 14      25 TARRAGONA BLVD    Attached House
# 15           59 VIELLA ST    Attached House
# 16           61 VIELLA ST    Attached House
# 17           64 VIELLA ST    Attached House
# 18           60 VIELLA ST    Attached House
# 19           62 VIELLA ST    Attached House
# 20           57 VIELLA ST    Attached House
# 21     119 TARRAGONA BLVD    Attached House
# 22     118 TARRAGONA BLVD    Attached House
# 23         522 WOBURN AVE    Detached House
# 24     397 ST GERMAIN AVE    Detached House
# 25     395 ST GERMAIN AVE    Detached House
# 26         1702 AVENUE RD  Small Commercial
# 27       58 BROOKMOUNT RD    Attached House
# 28      168 ELLIS PARK RD    Detached House
# 29        23 NAVENBY CRES    Attached House
# ...                   ...               ...
# 10107  10131 SHEPPARD AVE    Detached House
# 10108   3264 DANFORTH AVE         Apartment
# 10109     40 SHEPPARD AVE            Office
# 10110       292 FINCH AVE         Apartment
# 10111       16 HARBOUR ST  Small Commercial
# 10112   2965 SHEPPARD AVE    Detached House
# 10113         934 KING ST        Commercial
# 10114   2005 SHEPPARD AVE            Office
# 10115         507 KING ST            Office
# 10116    6015 STEELES AVE  Small Commercial
# 10117    6714 KINGSTON RD            Office
# 10118    1545 BATHURST ST         Apartment
# 10119    288 SHEPPARD AVE  Small Commercial
# 10120       91 TWELFTH ST    Detached House
# 10121     765 STEELES AVE  Small Commercial
# 10122    650 SHEPPARD AVE  Small Commercial
# 10123    575 DELAWARE AVE    Detached House
# 10124      1027 FINCH AVE        Commercial
# 10125    896 EGLINTON AVE         Apartment
# 10126       81 TWELFTH ST    Detached House
# 10127    157.5 TYRREL AVE    Attached House
# 10128     411 WILLARD AVE    Detached House
# 10129         401 KING ST        Commercial
# 10130         357 KING ST        Commercial
# 10131         560 KING ST        Commercial
# 10132     105 THE POND RD        Commercial
# 10133         431 KING ST        Commercial
# 10134   4227 SHEPPARD AVE        Commercial
# 10135         589 KING ST        Commercial
# 10136      1911 FINCH AVE        Commercial
#
# [10137 rows x 2 columns]

# %% [markdown]
# ### Retrieve Images

# %%
Tests = ["548 BROOKDALE AVE, Toronto, Ontario",
         "361 JOICEY BLVD, Toronto, Ontario"]

for i in Tests:
    GetStreet(Add=i,SaveLoc=myloc)
